# %%
import pandas
import matplotlib.pyplot as plt

data=[50,60,70,80,90]
plt.pie(data,labels={"sub1","sub2","sub3","sub4","sub5"},autopct='%1.2f%%',shadow=True)
plt.show()

# %%
import pandas
import matplotlib.pyplot as plt
age=[20,30,40,50]
income=[4000,8000,6512,84612]

plt.scatter(age,income,marker="s",c="yellow",linewidths=2,s=100,edgecolors="blue")
plt.xlabel=("age")
plt.xlabel=("income")

plt.show()
