# %%
import csv
i = 0

with open("C:/Users/User6/Desktop/CSV.file/Mobile phone price.csv","r")as file:
    data = csv.reader(file)
    for line in data:
        #print(line)
        if line[0] == "Samsung":
            print(line[0],line[1],line[7])
        count = 0
        while(count<1):
            count = count + 1
            print("Samsung")
# Out:
# Samsung
# Samsung
# Samsung Galaxy S21 Ultra 1199
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung Galaxy Z Flip3 999
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung Galaxy A52s 5G 449
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung Galaxy S21 799
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung Galaxy A22 5G 279
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung Galaxy A03s 139
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung Galaxy M52 5G 449
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung Galaxy A22 4G 229
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung Galaxy F22 189
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung Galaxy M12 159
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung Galaxy A52s 5G 459
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung Galaxy A72 429
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# Samsung
# ...

# %%
import csv
i=0

with open("C:/Users/User6/Desktop/KIAN.csv","r")as file:
    data=csv.reader(file)
    print(data)
    # for line in data:
    #     if line=="GP":
    #         print(line[0],line[1],line[2])
    #         count=0
    #         while(count<1):
    #             count=count+1
    #             print("school")

# %% [markdown]
# STATISTICAL LEARNING

# %%
import math
a=(2-4)**2+(2-4)**2+(3-4)**2+(4-4)**2+(6-4)**2+(7-4)**2
print(a)
# Out:
# 22

# %%
import math
print (math.sqrt(11/3))
# Out:
# 1.9148542155126762
